# %% [markdown]
# ## **SPAERIX INFOTECH - view our other projects her**-[Projects](https://sites.google.com/view/spaerixprojects/projects)

# %%
# Spaerix infotech - spaerixinfotech@gmail.com
import numpy as np 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# MRFO

# %%
def fun(X):
    output = sum(np.square(X))+random.random()
    return output

# This function is to initialize the  population.
def initial(pop, dim, ub, lb):
    X = np.zeros([pop, dim])
    for i in range(pop):
        for j in range(dim):
            X[i, j] = random.random()*(ub[j] - lb[j]) + lb[j]
    return X

# Calculate fitness values for each population.
def CaculateFitness1(X,fun):
    fitness = fun(X)
    return fitness

# Sort fitness.
def SortFitness(Fit):
    fitness = np.sort(Fit, axis=0)
    index = np.argsort(Fit, axis=0)
    return fitness,index


# Sort the position  according to fitness.
def SortPosition(X,index):
    Xnew = np.zeros(X.shape)
    for i in range(X.shape[0]):
        Xnew[i,:] = X[index[i],:]
    return Xnew


# Boundary detection function.
def BorderCheck1(X,lb,ub,dim):
        for j in range(dim):
            if X[j]<lb[j]:
                X[j] = ub[j]
            elif X[j]>ub[j]:
                X[j] = lb[j]
        return X

# %%
def rand_dim(Dim):
  randomlist2=[]
  for i in range(0,Dim):
        n = random.random()
        randomlist2.append(n)
  return randomlist2

# %%
def log_random(Dim):
  randomlist3=[]
  for i in range(0,Dim):
        n = random.random()
        nn=-math.log(n)
        randomlist3.append(nn)
  return randomlist3

# %%
import random
import time
import math

import numpy as np
rng = np.random.default_rng()
import math
import sys
from numpy import linalg as LA

low = -1
Up = 1
Dim = 34
nPop =10
Max_iter = 300               # Maximum number of iterations.

lb = low*np.ones([Dim, 1])
ub = Up*np.ones([Dim, 1])
X = initial(nPop, Dim, lb,ub)                    # Initialize 
fitness = np.zeros([nPop, 1])
for i in range(nPop):
  fitness[i] = CaculateFitness1(X[i, :], fun)
fitness, sortIndex = SortFitness(fitness)       # Sort the fitness values .
X = SortPosition(X, sortIndex)                  # Sort 
GbestScore = 100000                         # The optimal value for the current iteration.
GbestPositon = np.zeros([1, Dim])
GbestPositon[0, :] = X[0, :]
Curve = np.zeros([Max_iter, 1])
vec_flag=[1,-1]
vec_flag=np.array(vec_flag)
Xnew = np.zeros([nPop, Dim])
ybest=GbestScore 
for it in range (Max_iter):
  coef = it/Max_iter
  Fc=2-it*((2)/Max_iter)
  rr=random.random()
  r5=0.5
  if rr<r5:
    r1=random.random()
    beta = 2*math.exp(r1*((Max_iter-it+1)/Max_iter))*math.sin(2*math.pi*r1)
    if coef>random.random():
      Xnew[0,:]=GbestPositon+rand_dim(Dim)*(GbestPositon-X[0, :])+beta*(GbestPositon-X[0, :])
    else:
      IndivRand = initial(1, Dim, ub, lb)
      #print(IndivRand)
      Xnew[0,:]=IndivRand+rand_dim(Dim)*(IndivRand-X[0, :])+beta*(IndivRand-X[0, :])
  else:
    randomlist2 = np.array(rand_dim(Dim))
    randomlist3=np.array(log_random(Dim))
    r1_soa = random.random()
    r2_soa = random.random()
    A1=2*Fc*r1_soa-Fc
    C1=2*r2_soa
    b=1
    ll=(Fc-1)*random.random()+1
    Alpha = 2*randomlist2*(randomlist3)**0.5
    Xnew[0,:] = X[0, :]+rand_dim(Dim)*(GbestPositon-X[0, :])+Alpha*(GbestPositon-X[0, :]) #
  for i in range(nPop-1):
    rr=random.random()
    if rr<r5:
      r1=random.random()
      beta = 2*math.exp(r1*((Max_iter-it+1)/Max_iter))*math.sin(2*math.pi*r1)
      if coef>random.random():
        Xnew[i+1,:]=GbestPositon+rand_dim(Dim)*(X[i, :]-X[i+1, :])+beta*(GbestPositon-X[i+1, :])
      else:
        IndivRand = initial(1, Dim, ub, lb)
      #print(IndivRand)
        Xnew[0,:]=IndivRand+rand_dim(Dim)*(X[i, :]-X[i+1, :])+beta*(IndivRand-X[i+1, :])
    else:
      randomlist2 = np.array(rand_dim(Dim))
      randomlist3=np.array(log_random(Dim))
      r1_soa = random.random()
      r2_soa = random.random()
      A1=2*Fc*r1_soa-Fc
      C1=2*r2_soa
      b=1
      ll=(Fc-1)*random.random()+1
      Alpha = 2*randomlist2*(randomlist3)**0.5
      Xnew[0,:] = X[i+1, :]+rand_dim(Dim)*(X[i, :]-X[i+1, :])+Alpha*(GbestPositon-X[i+1, :])    
  for i1 in range(nPop):
     Xnew[i1,:] = BorderCheck1(Xnew[i1,:], lb, ub, Dim)
     tempFitness = CaculateFitness1(Xnew[i1,:], fun)     
     if (tempFitness<fitness[i1]):
         fitness[i1] = tempFitness
         X[i1, :] =Xnew[i1,:]

  for i2 in range(nPop):   
     if (fitness[i2] <= GbestScore):       
       GbestScore = fitness[i2]
       GbestPositon =  X[i2,:]
    
  Curve[it] = GbestScore

  
  print('Iteration: ',it)
  print('Best fitness:',Curve[it] )
# Out:
# Iteration:  0
# Best fitness: [0.08469251]
# Iteration:  1
# Best fitness: [0.08469251]
# Iteration:  2
# Best fitness: [0.08469251]
# Iteration:  3
# Best fitness: [0.04237388]
# Iteration:  4
# Best fitness: [0.00699481]
# Iteration:  5
# Best fitness: [0.00699481]
# Iteration:  6
# Best fitness: [0.00699481]
# Iteration:  7
# Best fitness: [0.00699481]
# Iteration:  8
# Best fitness: [0.00699481]
# Iteration:  9
# Best fitness: [0.00699481]
# Iteration:  10
# Best fitness: [0.00699481]
# Iteration:  11
# Best fitness: [0.00699481]
# Iteration:  12
# Best fitness: [0.00699481]
# Iteration:  13
# Best fitness: [0.00699481]
# Iteration:  14
# Best fitness: [0.00699481]
# Iteration:  15
# Best fitness: [0.00699481]
# Iteration:  16
# Best fitness: [0.00304505]
# Iteration:  17
# Best fitness: [0.00304505]
# Iteration:  18
# Best fitness: [0.00253585]
# Iteration:  19
# Best fitness: [0.00253585]
# Iteration:  20
# Best fitness: [0.00253585]
# Iteration:  21
# Best fitness: [0.00253585]
# Iteration:  22
# Best fitness: [0.00253585]
# Iteration:  23
# Best fitness: [0.00253585]
# Iteration:  24
# Best fitness: [0.00253585]
# Iteration:  25
# Best fitness: [0.00253585]
# Iteration:  26
# Best fitness: [0.00253585]
# Iteration:  27
# Best fitness: [0.00253585]
# Iteration:  28
# Best fitness: [0.00253585]
# Iteration:  29
# Best fitness: [0.00253585]
# Iteration:  30
# Best fitness: [0.00253585]
# Iteration:  31
# Best fitness: [0.00253585]
# Iteration:  32
# Best fitness: [0.00253585]
# Iteration:  33
# Best fitness: [0.00253585]
# Iteration:  34
# Best fitness: [0.00253585]
# Iteration:  35
# Best fitness: [0.00253585]
# Iteration:  36
# Best fitness: [0.00253585]
# Iteration:  37
# Best fitness: [0.00253585]
# Iteration:  38
# Best fitness: [0.00253585]
# Iteration:  39
# Best fitness: [0.00253585]
# Iteration:  40
# Best fitness: [0.00253585]
# Iteration:  41
# Best fitness: [0.00253585]
# Iteration:  42
# Best fitness: [0.00253585]
# Iteration:  43
# Best fitness: [0.00253585]
# Iteration:  44
# Best fitness: [0.00253585]
# Iteration:  45
# Best fitness: [0.00253585]
# Iteration:  46
# Best fitness: [0.00253585]
# Iteration:  47
# Best fitness: [0.00253585]
# Iteration:  48
# Best fitness: [0.00253585]
# Iteration:  49
# Best fitness: [0.00253585]
# Iteration:  50
# Best fitness: [0.00253585]
# Iteration:  51
# Best fitness: [0.00253585]
# Iteration:  52
# Best fitness: [0.00253585]
# Iteration:  53
# Best fitness: [0.00253585]
# Iteration:  54
# Best fitness: [0.00253585]
# Iteration:  55
# Best fitness: [0.00253585]
# Iteration:  56
# Best fitness: [0.00253585]
# Iteration:  57
# Best fitness: [0.00253585]
# Iteration:  58
# Best fitness: [0.00253585]
# Iteration:  59
# Best fitness: [0.00253585]
# Iteration:  60
# Best fitness: [0.00253585]
# Iteration:  61
# Best fitness: [0.00253585]
# Iteration:  62
# Best fitness: [0.00253585]
# Iteration:  63
# Best fitness: [0.00253585]
# Iteration:  64
# Best fitness: [0.00253585]
# Iteration:  65
# Best fitness: [0.00253585]
# Iteration:  66
# Best fitness: [0.00253585]
# Iteration:  67
# Best fitness: [0.00253585]
# Iteration:  68
# Best fitness: [0.00253585]
# Iteration:  69
# Best fitness: [0.00253585]
# Iteration:  70
# Best fitness: [0.00253585]
# Iteration:  71
# Best fitness: [0.00253585]
# Iteration:  72
# Best fitness: [0.00253585]
# Iteration:  73
# Best fitness: [0.00253585]
# Iteration:  74
# Best fitness: [0.00253585]
# Iteration:  75
# Best fitness: [0.00253585]
# Iteration:  76
# Best fitness: [0.00253585]
# Iteration:  77
# Best fitness: [0.00253585]
# Iteration:  78
# Best fitness: [0.00253585]
# Iteration:  79
# Best fitness: [0.00253585]
# Iteration:  80
# Best fitness: [0.00253585]
# Iteration:  81
# Best fitness: [0.00253585]
# Iteration:  82
# Best fitness: [0.00253585]
# Iteration:  83
# Best fitness: [0.00253585]
# Iteration:  84
# Best fitness: [0.00253585]
# Iteration:  85
# Best fitness: [0.00253585]
# Iteration:  86
# Best fitness: [0.00253585]
# Iteration:  87
# Best fitness: [0.00253585]
# Iteration:  88
# Best fitness: [0.00253585]
# Iteration:  89
# Best fitness: [0.00253585]
# Iteration:  90
# Best fitness: [0.00253585]
# Iteration:  91
# Best fitness: [0.00253585]
# Iteration:  92
# Best fitness: [0.00253585]
# Iteration:  93
# Best fitness: [0.00253585]
# Iteration:  94
# Best fitness: [0.00253585]
# Iteration:  95
# Best fitness: [0.00253585]
# Iteration:  96
# Best fitness: [0.00253585]
# Iteration:  97
# Best fitness: [0.00253585]
# Iteration:  98
# Best fitness: [0.00253585]
# Iteration:  99
# Best fitness: [0.00253585]
# Iteration:  100
# Best fitness: [0.00253585]
# Iteration:  101
# Best fitness: [0.00253585]
# Iteration:  102
# Best fitness: [0.00253585]
# Iteration:  103
# Best fitness: [0.00253585]
# Iteration:  104
# Best fitness: [0.00253585]
# Iteration:  105
# Best fitness: [0.00253585]
# Iteration:  106
# Best fitness: [0.00253585]
# Iteration:  107
# Best fitness: [0.00253585]
# Iteration:  108
# Best fitness: [0.00253585]
# Iteration:  109
# Best fitness: [0.00253585]
# Iteration:  110
# Best fitness: [0.00253585]
# Iteration:  111
# Best fitness: [0.00253585]
# Iteration:  112
# Best fitness: [0.00253585]
# Iteration:  113
# Best fitness: [0.00253585]
# Iteration:  114
# Best fitness: [0.00253585]
# Iteration:  115
# Best fitness: [0.00074329]
# Iteration:  116
# Best fitness: [0.00074329]
# Iteration:  117
# Best fitness: [0.00074329]
# Iteration:  118
# Best fitness: [0.00074329]
# Iteration:  119
# Best fitness: [0.00074329]
# Iteration:  120
# Best fitness: [0.00074329]
# Iteration:  121
# Best fitness: [0.00074329]
# Iteration:  122
# Best fitness: [0.00074329]
# Iteration:  123
# Best fitness: [0.00074329]
# Iteration:  124
# Best fitness: [0.00074329]
# Iteration:  125
# Best fitness: [0.00074329]
# Iteration:  126
# Best fitness: [0.00074329]
# Iteration:  127
# Best fitness: [0.00074329]
# Iteration:  128
# Best fitness: [0.00074329]
# Iteration:  129
# Best fitness: [0.00074329]
# Iteration:  130
# Best fitness: [0.00074329]
# Iteration:  131
# Best fitness: [0.00074329]
# Iteration:  132
# Best fitness: [0.00074329]
# Iteration:  133
# Best fitness: [0.00074329]
# Iteration:  134
# Best fitness: [0.00074329]
# Iteration:  135
# Best fitness: [0.00074329]
# Iteration:  136
# Best fitness: [0.00074329]
# Iteration:  137
# Best fitness: [0.00074329]
# Iteration:  138
# Best fitness: [0.00074329]
# Iteration:  139
# Best fitness: [0.00074329]
# Iteration:  140
# Best fitness: [0.00074329]
# Iteration:  141
# Best fitness: [0.00074329]
# Iteration:  142
# Best fitness: [0.00074329]
# Iteration:  143
# Best fitness: [0.00074329]
# Iteration:  144
# Best fitness: [0.00074329]
# Iteration:  145
# Best fitness: [0.00074329]
# Iteration:  146
# Best fitness: [0.00074329]
# Iteration:  147
# Best fitness: [0.00074329]
# Iteration:  148
# Best fitness: [0.00074329]
# Iteration:  149
# Best fitness: [0.00074329]
# Iteration:  150
# Best fitness: [0.00074329]
# Iteration:  151
# Best fitness: [0.00074329]
# Iteration:  152
# Best fitness: [0.00074329]
# Iteration:  153
# Best fitness: [0.00074329]
# Iteration:  154
# Best fitness: [0.00074329]
# Iteration:  155
# Best fitness: [0.00074329]
# Iteration:  156
# Best fitness: [0.00074329]
# Iteration:  157
# Best fitness: [0.00074329]
# Iteration:  158
# Best fitness: [0.00074329]
# Iteration:  159
# Best fitness: [0.00074329]
# Iteration:  160
# Best fitness: [0.00074329]
# Iteration:  161
# Best fitness: [0.00074329]
# Iteration:  162
# Best fitness: [0.00074329]
# Iteration:  163
# Best fitness: [0.00074329]
# Iteration:  164
# Best fitness: [0.00074329]
# Iteration:  165
# Best fitness: [0.00074329]
# Iteration:  166
# Best fitness: [0.00074329]
# Iteration:  167
# Best fitness: [0.00074329]
# Iteration:  168
# Best fitness: [0.00074329]
# Iteration:  169
# Best fitness: [0.00074329]
# Iteration:  170
# Best fitness: [0.00074329]
# Iteration:  171
# Best fitness: [0.00074329]
# Iteration:  172
# Best fitness: [0.00074329]
# Iteration:  173
# Best fitness: [0.00074329]
# Iteration:  174
# Best fitness: [0.00074329]
# Iteration:  175
# Best fitness: [0.00074329]
# Iteration:  176
# Best fitness: [0.00074329]
# Iteration:  177
# Best fitness: [0.00074329]
# Iteration:  178
# Best fitness: [0.00074329]
# Iteration:  179
# Best fitness: [0.00074329]
# Iteration:  180
# Best fitness: [0.00074329]
# Iteration:  181
# Best fitness: [0.00074329]
# Iteration:  182
# Best fitness: [0.00074329]
# Iteration:  183
# Best fitness: [0.00074329]
# Iteration:  184
# Best fitness: [0.00074329]
# Iteration:  185
# Best fitness: [0.00074329]
# Iteration:  186
# Best fitness: [0.00074329]
# Iteration:  187
# Best fitness: [0.00074329]
# Iteration:  188
# Best fitness: [0.00074329]
# Iteration:  189
# Best fitness: [0.00074329]
# Iteration:  190
# Best fitness: [0.00074329]
# Iteration:  191
# Best fitness: [0.00074329]
# Iteration:  192
# Best fitness: [0.00074329]
# Iteration:  193
# Best fitness: [0.00074329]
# Iteration:  194
# Best fitness: [0.00074329]
# Iteration:  195
# Best fitness: [0.00074329]
# Iteration:  196
# Best fitness: [0.00074329]
# Iteration:  197
# Best fitness: [0.00074329]
# Iteration:  198
# Best fitness: [0.00074329]
# Iteration:  199
# Best fitness: [0.00074329]
# Iteration:  200
# Best fitness: [0.00074329]
# Iteration:  201
# Best fitness: [0.00074329]
# Iteration:  202
# Best fitness: [0.00074329]
# Iteration:  203
# Best fitness: [0.00074329]
# Iteration:  204
# Best fitness: [0.00074329]
# Iteration:  205
# Best fitness: [0.00074329]
# Iteration:  206
# Best fitness: [0.00074329]
# Iteration:  207
# Best fitness: [0.00074329]
# Iteration:  208
# Best fitness: [0.00074329]
# Iteration:  209
# Best fitness: [0.00074329]
# Iteration:  210
# Best fitness: [0.00074329]
# Iteration:  211
# Best fitness: [0.00074329]
# Iteration:  212
# Best fitness: [0.00074329]
# Iteration:  213
# Best fitness: [0.00074329]
# Iteration:  214
# Best fitness: [0.00074329]
# Iteration:  215
# Best fitness: [0.00074329]
# Iteration:  216
# Best fitness: [0.00074329]
# Iteration:  217
# Best fitness: [0.00074329]
# Iteration:  218
# Best fitness: [0.00074329]
# Iteration:  219
# Best fitness: [0.00074329]
# Iteration:  220
# Best fitness: [0.00074329]
# Iteration:  221
# Best fitness: [0.00074329]
# Iteration:  222
# Best fitness: [0.00074329]
# Iteration:  223
# Best fitness: [0.00074329]
# Iteration:  224
# Best fitness: [0.00074329]
# Iteration:  225
# Best fitness: [0.00074329]
# Iteration:  226
# Best fitness: [0.00074329]
# Iteration:  227
# Best fitness: [0.00074329]
# Iteration:  228
# Best fitness: [0.00074329]
# Iteration:  229
# Best fitness: [0.00074329]
# Iteration:  230
# Best fitness: [0.00074329]
# Iteration:  231
# Best fitness: [0.00074329]
# Iteration:  232
# Best fitness: [0.00074329]
# Iteration:  233
# Best fitness: [0.00074329]
# Iteration:  234
# Best fitness: [0.00074329]
# Iteration:  235
# Best fitness: [0.00074329]
# Iteration:  236
# Best fitness: [0.00074329]
# Iteration:  237
# Best fitness: [0.00074329]
# Iteration:  238
# Best fitness: [0.00074329]
# Iteration:  239
# Best fitness: [0.00074329]
# Iteration:  240
# Best fitness: [0.00074329]
# Iteration:  241
# Best fitness: [0.00074329]
# Iteration:  242
# Best fitness: [0.00074329]
# Iteration:  243
# Best fitness: [0.00074329]
# Iteration:  244
# Best fitness: [0.00074329]
# Iteration:  245
# Best fitness: [0.00074329]
# Iteration:  246
# Best fitness: [0.00074329]
# Iteration:  247
# Best fitness: [0.00074329]
# Iteration:  248
# Best fitness: [0.00074329]
# Iteration:  249
# Best fitness: [0.00074329]
# Iteration:  250
# Best fitness: [0.00074329]
# Iteration:  251
# Best fitness: [0.00074329]
# Iteration:  252
# Best fitness: [0.00074329]
# Iteration:  253
# Best fitness: [0.00074329]
# Iteration:  254
# Best fitness: [0.00074329]
# Iteration:  255
# Best fitness: [0.00074329]
# Iteration:  256
# Best fitness: [0.00074329]
# Iteration:  257
# Best fitness: [0.00074329]
# Iteration:  258
# Best fitness: [0.00074329]
# Iteration:  259
# Best fitness: [0.00074329]
# Iteration:  260
# Best fitness: [0.00074329]
# Iteration:  261
# Best fitness: [0.00074329]
# Iteration:  262
# Best fitness: [0.00074329]
# Iteration:  263
# Best fitness: [0.00074329]
# Iteration:  264
# Best fitness: [0.00074329]
# Iteration:  265
# Best fitness: [0.00074329]
# Iteration:  266
# Best fitness: [0.00074329]
# Iteration:  267
# Best fitness: [0.00074329]
# Iteration:  268
# Best fitness: [0.00074329]
# Iteration:  269
# Best fitness: [0.00074329]
# Iteration:  270
# Best fitness: [0.00074329]
# Iteration:  271
# Best fitness: [0.00074329]
# Iteration:  272
# Best fitness: [0.00074329]
# Iteration:  273
# Best fitness: [0.00074329]
# Iteration:  274
# Best fitness: [0.00054162]
# Iteration:  275
# Best fitness: [0.00054162]
# Iteration:  276
# Best fitness: [0.00054162]
# Iteration:  277
# Best fitness: [0.00054162]
# Iteration:  278
# Best fitness: [0.00054162]
# Iteration:  279
# Best fitness: [0.00054162]
# Iteration:  280
# Best fitness: [0.00054162]
# Iteration:  281
# Best fitness: [0.00054162]
# Iteration:  282
# Best fitness: [0.00054162]
# Iteration:  283
# Best fitness: [0.00054162]
# Iteration:  284
# Best fitness: [0.00054162]
# Iteration:  285
# Best fitness: [0.00054162]
# Iteration:  286
# Best fitness: [0.00054162]
# Iteration:  287
# Best fitness: [0.00054162]
# Iteration:  288
# Best fitness: [0.00054162]
# Iteration:  289
# Best fitness: [0.00054162]
# Iteration:  290
# Best fitness: [0.00054162]
# Iteration:  291
# Best fitness: [0.00054162]
# Iteration:  292
# Best fitness: [0.00054162]
# Iteration:  293
# Best fitness: [0.00054162]
# Iteration:  294
# Best fitness: [0.00054162]
# Iteration:  295
# Best fitness: [0.00054162]
# Iteration:  296
# Best fitness: [0.00054162]
# Iteration:  297
# Best fitness: [0.00054162]
# Iteration:  298
# Best fitness: [0.00054162]
# Iteration:  299
# Best fitness: [0.00054162]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot( Curve,color='dodgerblue', marker='o', markeredgecolor='k', markerfacecolor='dodgerblue')

ax.set_xlabel('Number of Iterations',fontsize=15)
ax.set_ylabel('Fitness',fontsize=15)
ax.set_title(' Manta Ray Foraging Optimization')
plt.show()
